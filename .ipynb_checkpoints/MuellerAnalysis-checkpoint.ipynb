# %%
import PyPDF2
import itertools
import spacy
import networkx
import pandas as pd
import matplotlib.pyplot as plt
from spacy.matcher import PhraseMatcher
from spacy.tokens import Span
import math
import re
import seaborn as sns

# %%
mueller1 = open('Mueller-Report.pdf', 'rb')

# %%
mueller1Reader = PyPDF2.PdfFileReader(mueller1)

# %%
muellerPages = []
for pageNum in range(mueller1Reader.numPages):
    muellerPages.append(mueller1Reader.getPage(pageNum).extractText().split('\n'))
mueller1.close()

# %%
muellerParagraphs = sum(muellerPages,[]) #flatten the list of lists

# %%
len(muellerParagraphs)
# Out:
# 897

# %%
nlp = spacy.load('C:/Users/mj514/Anaconda3/lib/site-packages/en_core_web_lg/en_core_web_lg-2.0.0')

# %%
#From spacy documentation
class EntityMatcher(object):
    name = "entity_matcher"

    def __init__(self, nlp, terms, label):
        patterns = [nlp.make_doc(text) for text in terms]
        self.matcher = PhraseMatcher(nlp.vocab)
        self.matcher.add(label, None, *patterns)

    def __call__(self, doc):
        matches = self.matcher(doc)
        for match_id, start, end in matches:
            span = Span(doc, start, end, label=match_id)
            doc.ents = list(doc.ents) + [span]
        return doc

terms = (u"collude", u"collusion", u"conspiracy", u"conspire",u"hack", u"hacking", u"cyber intrusions", u"russian hacking", u"hackers",u"social media",u"computer intrusions",u"cybersecurity")
concept_matcher = EntityMatcher(nlp, terms, "THEME")

nlp.add_pipe(concept_matcher, after="ner")

print(nlp.pipe_names)  # The components in the pipeline

doc = nlp(u"This is a hacking, collusion, text about Barack Obama and a tree kangaroo")
print([(ent.text, ent.label_) for ent in doc.ents])
# Out:
# ['tagger', 'parser', 'ner', 'entity_matcher']
# [('hacking', 'THEME'), ('collusion', 'THEME'), ('Barack Obama', 'PERSON')]

# %%
nlpParagraphs= list(nlp.pipe(muellerParagraphs, n_threads=16, batch_size=50))

# %%
from collections import Counter
aDoc = nlpParagraphs[203]

entCountDict = Counter([(ent.text, ent.label_) for ent in doc.ents if not re.match(r"\.", ent.text) and (ent.label_=='GPE' or ent.label_ =='PERSON' or ent.label_ =='THEME') ])

for k,v in entCountDict.items():
    print(f"Label: {k[1]} text:{k[0]} count:{v}")
# Out:
# Label: THEME text:hacking count:1
# Label: THEME text:collusion count:1
# Label: PERSON text:Barack Obama count:1

# %% [markdown]
# # Tried using fuzzy wuzzy library to dedup
# Wasn't happy with results so I don't use it, but feel free to try it out.

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning [fuzz.py:11]

# %%
ents = [[ent.text.strip() for ent in doc.ents if not re.match(r"\.", ent.text) 
         and (ent.label_=='GPE' or ent.label_ =='PERSON' or ent.label_ =='THEME')] for doc in nlpParagraphs]
distinctEnts = list(set(sum(ents,[])))

# %%
dedupDict = {}
for i in range(len(distinctEnts)):
    if(i%10 == 0):
        print(len(distinctEnts))
    searchTerm = distinctEnts.pop(0)
    matchList = process.extractBests(searchTerm, distinctEnts[1:],score_cutoff=90)
    
    if(len(matchList) == 0):
        dedupDict[searchTerm] = searchTerm
    else:
        print(searchTerm)
        print(matchList)
        for m in matchList:
            dedupDict[m[0]] = searchTerm
            distinctEnts.remove(m[0])
# Out:
# 2445
# Girard
# [('G.', 90)]
# 708 Cohen
# [('CoH', 90), ('° Cohen', 90), ('Cohen', 90)]
# A. Agalarov
# [('Agalarov', 95), ('E. Agalarov', 91)]
# Kuznetsov
# [('Sergey Kuznetsov', 90), ('Jared Kuznetsov', 90)]
# Porter
# [('Michael Porter', 90), ('message.801 Porter', 90), ('Rob Porter', 90), ('o/', 90), ('Porter Undated Notes', 90)]
# Z. Cohen
# [('C. §', 90), ('E.', 90), ('e~', 90)]
# supp0ti McGahn's
# [('McGahn', 90)]
# Preteetecl Uflcler Fecl
# [('Preteetecl UHcler Fecl', 93), ('Preteeted Uflcler Fecl', 93), ('Preteetecl Uttcler Fecl', 91), ('Fecl', 90)]
# 2414
# convention."934
# [('Convention', 90), ('IO', 90)]
# Donald Trump Jr.
# [('Donald Trump Jr', 100), ('Donald Trump Jr.-', 100), ('Donald J. Trump Jr.', 95), ('Donald J. Trump Jr.,96', 95), ('Donald Trump', 95)]
# Mifsud
# [('Joseph Mifsud', 90), ('f.', 90), ('Yuriy Mifsud', 90)]
# Tierney Sneed
# [('Ed', 90)]
# Oganov
# [('Georgiy Oganov', 90), ('Georgy S. Oganov', 90), ('V.', 90)]
# Gonzales
# [('\\l', 90)]
# Michael Flynn Jr.
# [('Michael Flynn-', 95), ('Michael Flynn', 95), ('Michael Flynn m', 90), ('Flynn', 90), ('Michael', 90)]
# 2384
# John Kelly
# [('Kelly', 90), ('JO', 90), ('Ll', 90)]
# Rex Timofeev
# [('Timofeev', 90), ('Mo', 90), ('FeE', 90)]
# Robert (Bob
# [('Rob', 90)]
# Atterney Werk
# [('AtterAey Werk', 92), ('Wer', 90), ('Atterne', 90), ('Atterney', 90), ('Werk', 90)]
# Rehnquist
# [('St.', 90)]
# 563 Devlin Barrett et al
# [('Devlin Barrett et al', 95)]
# Yuri Viktorovich Vaino
# [('Vaino', 90), ('Viktor', 90)]
# Matt Skiber
# [('Matt Skibe', 95), ('Ma~', 90), ('Ma', 90), ('// Ma', 90)]
# 2354
# Mttterittl Preteetea UAaer Fea
# [('Mttterittl Proteetea Unser Fea', 90), ('Mttterittl', 90), ('Mttterittl Preteetea', 90), ('Mttt', 90)]
# Stone
# [('back?"685 Goldstone', 90), ('Goldstone', 90), ('Kaveladze Goldstone', 90), ('Goldstone Facebook', 90), ('Michael Goldstone', 90)]
# Stephen
# [('Stephen Millian', 90), ('Stephen Miller', 90), ('Stephen Collinson', 90), ('Stephen Bannon', 90)]
# Corney Overview Corney
# [('° Corney', 90), ('Overview', 90), ('Corney', 90)]
# Richard Oates's
# [('Richard', 90)]
# Cohen 1
# [('Cohen 11/12/18 302', 90), ('Cohen 979 Cohen 11/12/18 302', 90), ('Cohen 11/20/19 302', 90), ('Cohen 12/12/18', 90), ('Cohen 11/20/18 302', 90)]
# 2322
# Kisl ak
# [('K.', 90)]
# Logan Act
# [('Logan', 90)]
# Mtty Cefltaifl
# [('Mtty Cefl', 90), ('Ifl', 90), ('Cefl', 90), ('Mtt', 90), ('Ce', 90)]
# Polonskaya
# [('Elena Polonskaya', 90), ('Olga Polonskaya', 90)]
# Flynn 1/19/18
# [('Flynn 1/19/18 302', 95), ('° Flynn 1/11/18', 92), ('Flynn 1', 90), ('Fl', 90), ('° Flynn', 90)]
# Bannon.547 Ruddy
# [('RU', 90), ('Ruddy', 90), ('Bannon', 90)]
# Sess
# [('Sessions to stay.519', 90), ('Sessions.749 Hicks', 90), ('Sessions', 90), ('A.G. Jeff Sessions', 90), ('Sessions.625 Lewandowski', 90)]
# POTUS
# [('US', 90)]
# Axelrod
# [('Rod', 90)]
# Jason Greenblatt
# [('Greenblatt', 90)]
# 2287
# Gordon
# [('speakers.780 Gordon', 90), ('amendment.799 Gordon', 90), ('J.D. Gordon', 90), ('Gordon et al', 90), ('assistance."814 Gordon', 90)]
# Roy Cohn
# [('Cohn', 90)]
# R. Crim
# [('I. R. Crim', 95), ('R. Cri', 92), ('UHaer Fee:!. R. Crim', 90)]
# AMerttey Werk
# [('AMerttey Werk Prec', 95)]
# follow.1080 Dmitriev
# [('Dmitriev', 90)]
# McFarland
# [('Administration.1260 McFarland', 90), ('McFarland 11/22/17 302', 90), ('McFarland 2/26/17 Memorandum', 90), ('K.T. McFarland', 90), ('McFarland 12/22/', 90)]
# Graffto Macchia
# [('Graff', 90), ('iA', 90)]
# event.620 Saunders
# [('Saunders', 90)]
# Nork Produet
# [('Nork', 90)]
# 2257
# Konstantin Kilimnik
# [('Kilimnik', 90)]
# Fea
# [('Werk Pfeattet', 90), ('Uttaer Fea', 90), ('UHaer Fea', 90), ('Prateeteti URaer Fea', 90), ('Eier Fea', 90)]
# Kirill Dmitriev's
# [('Kirill Dmitriev', 95), ('Ill.', 90)]
# D.C. Cir
# [('(D.C. Cir', 100), ('D.C.', 90), ('D.C', 90), ('1132 (D.C. Cir', 90)]
# RDIF.1101 Dmitriev
# [('RDIF', 90)]
# Jack
# [('Jack Stubbs', 90), ('J.', 90), ('Jackson', 90)]
# Patts
# [('Pa.', 90)]
# conference.478 Sanders
# [('Sanders', 90)]
# 2229
# TRUMPORG_16_00141
# [('UMPORG', 90), ('Trump', 90), ('Trum', 90)]
# the Ian
# [('Ian', 90)]
# Viktor Boyarkin,857
# [('Boyarkin', 90)]
# Ellen Nakashima
# [('Ellen Nakashima et al', 95)]
# Donald J. Trump
# [('DONALD J. TRUMP', 100), ('Donald J Trump', 97), ("Donald J. Trump's", 95), ('DONALD J. TRUMP I.', 95), ('Donald J. Trump Jr.103', 95)]
# Hicks
# [('Hicks 3/', 95), ('511 Hicks', 90), ('471 Hicks', 90), ('Jacob Hicks', 90), ('Hicks 3/13/ l', 90)]
# ofMichael Cohen
# [('Michael Cohen', 93)]
# Seth Rich."180 Likewise
# [('Ike', 90), ('Seth Rich', 90)]
# 2200
# Motet
# [('Mot', 90)]
# Rozov et al
# [('Rozov', 90)]
# Young
# [('Karen De Young', 90), ('Karen DeYoung', 90)]
# Yevgeniy Prigozhin
# [('Yevgeny Prigozhin', 97), ('Prigozhin', 90), ('Pri', 90)]
# Magnitsky Case
# [('Magnitsky', 90)]
# Robert Mueller
# [('Robert S. Mueller II', 95), ('Robert S. Mueller', 95), ('Mueller', 90), ('Robert Mueller Impanels', 90)]
# Werle Prnat
# [('Werle', 90)]
# DJTJR00446
# [('Jr.', 90), ('Jr', 90)]
# Kislyak.1219
# [('Kislyak', 90)]
# 2174
# President.445 Dhillon
# [('Dhillon', 90)]
# Miller
# [('802 M. Miller', 90), ('404 S. Miller', 90), ('407 S. Miller', 90), ('S. Miller', 90), ('Jason Miller', 90)]
# United States v. Petruk
# [('v. United States', 95), ('Petruk', 90), ('United States', 90), ('States', 90), ('" United States', 90)]
# McGee
# [('McGee et al', 90), ('Gee', 90)]
# CeHtaifl
# [('CeHta', 90), ('CE', 90)]
# Werk Prnettet
# [('Werk Predttet //', 92), ('Werk Predttet', 92), ('Werk Preattet', 92)]
# 2146
# investigation.430
# [('investigation.307', 94)]
# \1/erk PreElttet
# [('Nerk PreElttet //', 90), ('Werk Preelttet', 90)]
# Ekim Alptekin US
# [('Alptekin', 90)]
# Podesta
# [('Richard Podesta', 90), ('John Podesta.49', 90), ("John Podesta's", 90), ('John Podesta', 90)]
# Dearborn
# [('Rick Dearborn.612', 90), ('Rick Dearborn', 90), ('Jr. Dearborn', 90)]
# R. Ct'im
# [('R. Ct·im', 93), ('R. Ctim', 93)]
# Mftteriftl
# [('Mf', 90), ('Mft', 90)]
# Amber Phillips
# [('21 Amber Phillips', 95), ('MB', 90)]
# 2119
# Seychelles
# [('Seychelles.1082', 90), ('the Seychelles Trip', 90), ('Erik Prince Arrange Seychelles', 90)]
# Westerhoutto Flaherty
# [('Flaherty', 90)]
# Dmitry Phares
# [('Dmitry', 90)]
# R. Cl'iffl
# [("R. Cl'itfl", 90), ("R. Ct'iffl", 90)]
# Natalia Veselnitzkaya
# [('Natalia Veselnitskaya', 95), ('Natalia Yeselnitskaya', 90)]
# Page Memorandum
# [('Page', 90), ('Mem', 90)]
# Rudy Giuliani
# [('Giuliani', 90)]
# David E. Sanger
# [('David', 90)]
# 2096
# Erik Prince's
# [('Erik Prince', 95), ('Prince', 90)]
# Dvorkovich
# [('Russia.1200 Dvorkovich', 90), ('Arkady Dvorkovich', 90), ('Annie Dvorkovich', 90)]
# Sanders 7
# [('Sanders 7 /23/18', 90), ('Sanders 7 /3/18', 90), ('Sanders 7/3/18 302', 90)]
# Obama
# [('Barack Obama', 90)]
# Bannon 2/14/18 302
# [('Bannon 2/14/18', 95), ('Bannon 2/', 90)]
# Victor
# [('Victor Podobnyy', 90), ('Victor Poliakova', 90)]
# Wagner
# [('John Wagner', 90)]
# 2072
# May Cefttaifl
# [('May Cefltaifl', 92), ('May', 90), ('May Ce', 90)]
# May Cefltatfl
# [('May Cefl', 90)]
# Sam
# [('Walid/Sam', 90), ('1 Samuel Johnson', 90), ('Samochomov', 90), ('Darren Samuelsohn', 90), ('W. Samuel Patten', 90)]
# Samochornov 7/12/17 302
# [('Samochornov 7/13/17 302', 96), ('Samochornov 7/12/17', 95), ('Samochornov', 90), ('Samochornov 7', 90)]
# the United States's
# [('the United States', 95), ('ted', 90), ('Ted', 90)]
# 2046
# R. Cril'l'I. P. 6(e
# [("R. Crifl'I. P. 6(e", 92), ('P. 6(e', 90)]
# Transcript
# [('SC', 90), ('Transcript-Donald Trump Jr', 90), ('2/13/19 Transcript', 90), ('Cohen 8/21/18 Transcript', 90), ('Jake Tapper Transcript', 90)]
# 1019 Cohen
# [('1016 Cohen', 90)]
# Vandalia
# [('Va.', 90)]
# 2027
# Werle Predttet
# [('Werle Preattet', 93), ('Predt', 90), ('Werle Prnelttet', 90)]
# I198 Weber
# [('Weber', 90)]
# Russia.929
# [('Russia', 90)]
# Vladimir Putin.423
# [('Vladimir Putin', 95), ('Vladimir', 90), ('Putin', 90)]
# Crimea
# [('Occupation of Crimea', 90)]
# Burt 2/9/18
# [('Burt 2/9/18 302', 95), ('Burt', 90)]
# 2006
# Alex van der
# [('Alex van der Zwaan', 90)]
# Preattet II Mtt
# [('Preattet', 90), ('II', 90)]
# Cetttaitt MU-1:erial Preteetea
# [('Cetttaitt', 90)]
# Mttterittl Proteetee
# [('Mttterittl Proteeted', 95), ('Mttterittl Proteetea', 95), ('Mttterittl Proteeteci', 93), ('Proteetee', 90), ('Mttterittl Preteeted', 90)]
# 1987
# Mttterittl Proteetetl UHtler Fee
# [('Proteetet', 90)]
# Soviet Union
# [('the Soviet Union', 95)]
# Corey Lewandowski.603
# [('Corey Lewandowski', 95), ('Lewandowski', 90)]
# 1973
# 994 Nader 1/22/18
# [('993 Nader 1/22/18', 94), ('Nader 1', 90), ('Nader', 90)]
# Sean Spicer.132
# [('Sean Spicer', 95), ('Spicer', 90)]
# Donald
# [('Donald J. Trump.304 Sater', 90), ('Donaldson 4/2/ l', 90), ('Ki rill Donaldson', 90), ("Donald Trump's", 90), ('Donald Trump Son-in-', 90)]
# Miey CeRtttit1 Material Preteeteti Ut1tier Feti
# [('Preteetet', 90), ('Materia', 90)]
# 1951
# McCabe 8/17/17
# [('McCabe 8/17/17 302', 95), ('McCabe', 90)]
# Yuri Chaika.664 Aras Agalarov
# [('Aras Agalarov', 90), ('Aras', 90)]
# Sergei Gorkov
# [('Sergey Gorkov', 92), ('Sergei', 90), ('Gorkov', 90)]
# Hunt
# [('Hunt-000039', 90), ('Jody Hunt', 90), ('425 Hunt-000026', 90), ('Hunt-000032', 90), ('Hunt-000041', 90)]
# 1929
# Jeffrey
# [('Jeff', 90)]
# Werk Pretittet
# [('Werk Pretittet //', 100), ('Werk Preidttet', 93), ('Werk Pretlttet', 93), ("Werk Pt'etittet", 90), ('Tit', 90)]
# Gauhar-000060
# [('Gauhar-000056', 92), ('Gauhar', 90)]
# Carter
# [('Carter Pa e', 90), ('Carter Papadopoulos', 90), ("Carter Page's", 90), ('Carter Page', 90), ('Carter W. Page', 90)]
# Peter Baker et al
# [('Peter Baker', 90)]
# 1905
# Jared Kushner' s
# [("Jared Kushner's", 97), ("Jared Kushner'", 95), ('Jared Kushner', 95), ('° Kushner', 90), ('Kushner', 90)]
# Michael S. Schmidt et al
# [('Michael S. Schmidt', 95)]
# Alan Gates
# [('Gates', 90)]
# Papadopoulos.417
# [('Papadopoulos', 95)]
# Gucci fer 2.0
# [('Guccifer 2.0', 96), ('Guccifer 2.0 ...........................................................................................................', 96), ('Gucci fer', 95)]
# Rick Gates
# [('Rick', 90)]
# 1883
# matters."1131 Bob Foresman
# [('Foresman', 90)]
# Craig
# [('Gregory Craig', 90)]
# Mtty Cetttttifl
# [('May Cetttttifl', 90), ('Mtty CeHtttifl', 90), ('Mtty', 90)]
# Russia Hacked
# [('hack', 90)]
# Diana Deripaska
# [('Deripaska', 90)]
# 68Comey 11/15/17302,at3
# [('Comey', 90), ('Mey', 90)]
# 1864
# Rachel Weiner
# [('Wei', 90)]
# Henry Kissinger
# [('Henry', 90), ('Kissinger', 90)]
# Uttt
# [('Preteeteti Utttier Feti', 90), ('Preteeteti Utttier Fee', 90)]
# Steele reports.117
# [('Steele', 90)]
# Kislyak.126 Flynn
# [('Kislyak.1266 Flynn', 97)]
# Ivanka Trump
# [('Ivanka Trump.914', 95), ('Ivan Trump', 91), ('IV', 90)]
# 1844
# 138 S. Ct
# [('S. Ct', 90)]
# Mike Flynn Offers
# [('Mike Flynn', 90), ('Mike', 90)]
# CeHtttin Mttterittl Preteetee
# [('CeHtttiH Mttterittl Preteetea', 93)]
# UHder Fed
# [('Mttterittl Prnteeted UHder Fed', 90)]
# 1829
# Dmitri Klokov
# [('Dmitry Klokov', 92), ('Klokov', 90)]
# Simes et al
# [('Simes', 90)]
# DENMAN
# [('Denman', 100), ('Michael Denman', 90), ('Denman 12/4/17 302', 90), ('DENMAN 000012', 90), ('Denman 6/7/17 302', 90)]
# Julia Ioffe
# [('Julia Iofee', 91), ('Jul', 90)]
# Cohen 9112/18 302
# [('Cohen 9/', 90)]
# Alexander Bulatov
# [('Bulatov', 90)]
# 1807
# Paul Manafort Paul Manafort
# [('Manafort', 90), ('Paul Mana', 90), ("Paul Manafort'", 90), ('Mana', 90), ('Paul', 90)]
# New York City
# [('New', 90), ('New York', 90), ('York', 90)]
# Boris Kolesnikov,879
# [('Kolesnikov', 90)]
# Clinton
# [('Clintons', 93), ('Hillary Clinton', 90), ('Clinton.738', 90), ("Hillary Clinton's", 90), ('Hillary Clinton-', 90)]
# 1783
# Denis Katsyv,681
# [('Denis Katsyv', 95)]
# Documentary
# [('night.919 Documentary', 90)]
# Petr Aven's
# [('Petr Aven', 95), ("Petr A ven' s", 92), ('Aven', 90)]
# Gleb Veselnitskaya
# [('Veselnitskaya', 95)]
# Buryakov Com
# [('Buryakov', 90)]
# 1766
# Nilsen
# [('Sen', 90)]
# U.S
# [('U.S.', 100), ('U.s', 100), ('U.S. Persons', 90)]
# Peter Kaveladze
# [('Kaveladze', 90), ('° Kaveladze', 90)]
# Spencer Ackerman
# [('Pence', 90)]
# 1749
# Richard Burt.614
# [('Richard Burt', 95), ('14/', 90)]
# Mtty Cottt
# [('Mtty Cotttttitt Mttterittl Proteetea', 90), ('Mtty Cotttttitt', 90)]
# H]e
# [('Michael Kranish et al', 90), ('Glenn Thrush et al.', 90)]
# PaulJ. Manafort
# [('Paul J. Manafort', 97), ('Paul J Manafort', 93), ('Paul Manafort', 93)]
# 1730
# James Corney
# [('James B. Corney', 95)]
# Jerome Corsi
# [('Rome', 90), ('Corsi', 90)]
# 1717
# Walid
# [('Walid/Sam -FM', 90), ('Walid Pinedo', 90)]
# Sater
# [('Felix Sater.319 c. Letter', 90), ('Felix Sater', 90), ('Felix Sater Dvoskin', 90), ('Sarah Huckabee Sater', 90)]
# Pete Lavrov
# [('Lavrov', 90)]
# @WikiLeaks et al
# [('Wikileaks', 90)]
# Alice Donovan
# [('Don', 90)]
# 1698
# D.C.432
# [('D.D.C', 95)]
# Richard W. Gates III
# [('Richard W Gates III', 97)]
# Nader & Dmitriev
# [('Dmitriev Nader', 95)]
# Flynn.306 2
# [('Flynn 3/', 90)]
# \llerk
# [('\\llerk PreElttet', 90), ('\\llerk Preattet', 90)]
# 1682
# Moore
# [('@Pamela_ Moore 13', 90)]
# William Burnham
# [('William', 90), ('Burnham', 90)]
# McGahn l l/30/17 302
# [('McGahn l l', 90)]
# Wark Prsdttet
# [('Wark', 90)]
# Emin
# [('40 B. Dissemination', 90), ("Emin Agalarov's", 90), ('Emin Agalarov', 90), ('Emin Akhmetov', 90)]
# Mr
# [('MR', 100)]
# 1662
# Pompeo
# [('Olga Pompeo', 90), ('Michael Pompeo', 90), ('Mike Pompeo', 90)]
# Fowler
# [('v. Fowler', 90)]
# Sean Hannity,74
# [('Sean Hannity', 95), ('740 Sean Hannity', 92), ("Sean Hannity's", 90)]
# Jeter
# [('Jetter', 91)]
# office.362
# [('Office', 90)]
# Moscow
# [('Moscow City', 90), ('Moscow.910', 90), ('Moscow.912', 90), ('Moscow.455', 90), ('Trum Moscow', 90)]
# 1638
# Rhona Partner
# [('Rhona', 90), ('Tn', 90)]
# URder
# [('Mftferial Preteeted URder Fed', 90)]
# Rybicki 6/22/17
# [('Rybicki', 90)]
# Georgia.313 Cohen
# [('Georgia', 90)]
# Prevezon litigation.716 Kaveladze
# [('Prevezon', 90)]
# 1622
# Hamburg
# [('Steven Mufson & Tom Hamburger', 90), ('Tom Hamburger et al', 90)]
# Baranov
# [('Andrey Baranov', 90)]
# Trump,97 Kellyanne Conway,98 Brad
# [('Kellyanne Conway', 90), ('Conway', 90)]
# Tom
# [('Tombrello', 90), ('Attome', 90), ('Tom Bossert', 90), ('tomorrow."448', 90), ('Attomey Work Product/', 90)]
# 1602
# Sergey Ledeen
# [('Ledeen', 90)]
# George Papadopoulos
# [('George Papadopoulos Learns', 95), ('George Papadopoulos Post-', 95), ('George Papadopoulos-"committed', 90), ('George Papadopoulos George Papadopoulos', 90)]
# Egypt
# [('EGYPT', 100)]
# 1586
# 9 B. Investigative
# [('B. Investigative', 95)]
# Richard Pinedo Post
# [('Richard Pinedo', 95), ('Pinedo', 90)]
# Sergey Ryabkov
# [('Ryabkov', 90)]
# John Kerry
# [('Kerry', 90)]
# 1571
# Mohammed bin Zayed
# [('Mohammed', 90)]
# Harr
# [('Shane Harris', 90)]
# Attein1ey
# [('n1ey', 90)]
# Flynn et al
# [('Flynn et al.', 100)]
# Yatsenko
# [('Sergey Yatsenko.518', 90), ('Sally Yatsenko', 90)]
# 1555
# Carson
# [('Ben Carson', 90)]
# Bill Browder 's
# [('Bill Browder', 95), ('Browder', 90), ('Bill', 90)]
# Mfty Cm
# [('Cm', 90)]
# 1540
# UHE
# [('UHeer Fee', 90), ('UHeer', 90), ('UHeer Fed', 90)]
# Anatoli Sanders
# [('i]s', 90)]
# Work Proeuet
# [('Work', 90)]
# Guccifer 2.0 I.C.
# [('Guccifer', 90)]
# 1524
# CetttttiA Mttterittl
# [('Cetttttitt Mttterittl', 93)]
# Bartiromo
# [('Maria Bartiromo', 90)]
# Werk Preclttet //
# [('Werk Preclttet', 100), ('Werk Preflttet', 93), ('Werk Proclttet //', 93)]
# Michael Flynn's
# [('Michael Flynn US', 97)]
# 1508
# 1498
# 931 Cohen 9/12/18
# [('Cohen 9/18/18', 95), ('Cohen 9/12/18', 95), ('914 Cohen 9/12/18', 94)]
# Dimitri Simes
# [('Dimitri', 90), ('Dimitri Simes Connect', 90)]
# Peskov
# [('Jr. Peskov', 90), ('Dmitri Peskov', 90), ('Dmitry Peskov', 90), ('Pr_peskova@prpress.gov.ru', 90)]
# 1479
# research.261 Oknyansky
# [('Oknyansky', 90)]
# 1468
# Tom Winter & Ken Dilanian
# [('Ken Dilanian', 90)]
# Miey Cmitaitt
# [('Miey', 90), ('Cmi', 90)]
# 1455
# Ul'lder Fed
# [('der Fed', 90)]
# Richard Burr
# [('Burr', 90)]
# Clovis
# [('Sam Clovis', 90), ('Clovis et al', 90), ('James Clovis', 90)]
# 1440
# Boyko
# [('Charles Boyko', 90), ('Yuriy Boyko', 90)]
# Bo Denysyk
# [('Denysyk', 95)]
# Section III.D.2
# [('Sec', 90)]
# Reince Priebus
# [('Priebus', 90)]
# Robert Costello
# [('Costello', 90)]
# 1424
# Mey Cefl
# [("Mey Cefltail'l Matet·ial Preteetee", 90)]
# Gary Lee
# [('Lee', 90)]
# Flynn.164 Yates
# [('Yates', 90)]
# 1411
# Julian Assange
# [('Assange', 90), ('Assan', 90)]
# A. Russian
# [('174 A. Russian', 95)]
# 115th Cong
# [('116th Cong', 90), ('Cong', 90)]
# 1396
# Dempsey
# [('Rick Dempsey', 90), ('Michael Dempsey', 90)]
# Holder
# [('Eric Holder', 90)]
# 1383
# ° Caputo
# [('Caputo', 100), ('Michael Caputo', 90), ('Matt Caputo', 90)]
# Gerson 6/15/18.302
# [('Gerson', 90)]
# Alan Futerfas
# [('Futerfas', 90)]
# 1368
# CeHtaiH Matel'ial Pl'eteetea UHtfor
# [('CeHtaiH', 90)]
# Matt Apuzzo et al.
# [('Matt Apuzzo et al', 100)]
# Michael D. Shear & Maggie Haberman
# [('Maggie Haberman', 90)]
# 1355
# K.T.
# [('Flynn Tick Tock', 90)]
# Gary Williams
# [('Williams', 90)]
# 1343
# Michael Rogers.347
# [('Michael Rogers', 95), ('Rogers', 90)]
# McCabe 5/16/17 Memorandum 1
# [('McCabe 5/10/17 Memorandum', 92)]
# Louis Nelson
# [('53 Louis Nelson', 95)]
# 1329
# stance.810 Mashburn
# [('stance.816 Mashburn', 95)]
# UK
# [('Interfax-Ukraine', 90), ('Ukrainian', 90), ('Ukraine.794', 90), ('Yanukovych', 90), ('Pinchuk', 90)]
# 7/7/18
# [('7/27/18', 95)]
# Prikhodko
# [('Sergei Prikhodko', 90)]
# 1311
# Berkowitz
# [('AKIN_GUMP_BERKOWITZ_O0000l-04', 90), ('Ivanchenko to Berkowitz', 90), ('Andrey Berkowitz', 90)]
# Werk Pwettet //
# [('Werk Pwdttet', 92)]
# Jody Ivanov
# [('Jody', 90), ('Ivanov', 90)]
# 56 Jim Heintz
# [('Jim Heintz', 95)]
# campaign."509 Papadopoulos
# [('Campa', 90)]
# 1293
# Papadopoulos Statement of Offense
# [('Papadopoulos Statement', 90)]
# investigation.326 Boente
# [('Boente', 90)]
# Flynn 5/1/18 302
# [('Flynn 3/1/18 302', 94), ('Flynn 1/11/18 302', 91)]
# 1279
# Khoo et al
# [('Khoo', 90)]
# Sergey Kislyak
# [('Sergey Kislyak.1128', 95), ("Sergey Kislyak's", 95), ('Sergey Kislyak.79', 95)]
# Robert Goldstone
# [('Rob Goldstone', 90), ('Robert Goldstone Goldstone', 90)]
# Atttm1ey Wark Pradttet
# [('Pradttet //', 90), ('Wark Prad', 90)]
# 1261
# 1251
# Tony Blair
# [('Tony', 90)]
# Sergey Landrum
# [('Landrum', 90)]
# Steve
# [('Steve Bannon.989', 90), ('Steven Miiller-Maguhn', 90), ('Steve Bannon', 90), ('Steve Mnuchin', 90), ('Steve Holland', 90)]
# 1234
# Beniaminov
# [('Roman Beniaminov', 90)]
# Viktor Yanukovych."17
# [('Viktor Yanukovych', 95), ('Viktor Y', 90)]
# 1221
# 222 Christie
# [('Christie', 90)]
# Medvedev
# [('Dmitry Medvedev', 90)]
# Paul Manafort's
# [("Paul Manafort 's", 97)]
# 1208
# Indictment
# [('Indictment United States', 90)]
# 624 Lewandowski
# [('626 Lewandowski', 93)]
# 1196
# R. Griff!.
# [('R. Griff', 100), ('R. Griff!. P. 6(e', 90)]
# Preteeted Ufl:
# [('Preteeted', 95)]
# 1183
# Seeks
# [('Again Seeks', 90)]
# Corney 1/6/17 Memorandum
# [('Corney Memorandum', 95), ('Corney 1/28/17 Memorandum', 94), ('Corney 2/14/17 Memorandum', 90)]
# Joy Lutes
# [('Lutes', 90)]
# 1168
# HtttiH Mttterial Preteeteti Utttier Fee
# [('Mttteria', 90)]
# Russian Federation
# [('the Russian Federation', 95), ("the Russian Federation's", 95), ('the Russian Federation."317', 90)]
# WH000017685
# [('WH0000l7685', 91)]
# Smith
# [('Allan Smith', 90), ('Peter Smith', 90), ('money.277 Smith', 90)]
# 1150
# Andrei Rtskhiladze
# [('Rtskhiladze', 90)]
# Uruier Feti
# [('Feti', 90)]
# Thomas
# [('Thomas Barrack', 90)]
# 1137
# Ł
# [('Mtt:,Ł', 90), ('I. Ł', 90), ('Ł Ł u', 90)]
# Dana Bogacheva
# [('Anna Bogacheva', 93), ('Dana', 90)]
# Bradley Patten
# [('Patten', 90)]
# 147 SCR015_000198
# [('SCR015_000198', 95)]
# 1120
# Cruz
# [('Ted Cruz', 90)]
# 1109
# hacking
# [('A. GRU Hacking Directed', 90)]
# Anton Kobyakov
# [('Anton', 90), ('Kobyakov', 90)]
# Reagan
# [('Ronald Reagan', 90)]
# 1095
# R. Cri1t1
# [('R. Cri1T1', 100)]
# Fabrizio to Ward
# [('Fabrizio', 90)]
# Linkedln
# [('Linkedln Message', 90), ('Papadopoulos Linkedln', 90)]
# R. CFiffl
# [('R. Cfiffl', 100)]
# Lana
# [('Lana Erchova', 90), ('Lana E. Alexander', 90), ('Lana Alexander', 90)]
# 1077
# Crooked Hillary
# [("Crooked Hillary's", 95), ('Hillary', 90)]
# Jason Fishbein
# [('Fishbein', 90)]
# 1064
# 1054
# Holt
# [('Lester Holt', 90), ('Hope Holt', 90)]
# Rachel Brand.739
# [('Rachel Brand', 95)]
# Boyd
# [('Charles Boyd', 90), ('Viktor Boyd', 90), ('Boyd et al', 90)]
# 1038
# Michael T. Flynn 1231 Flynn
# [('Michael Flynn Michael Flynn', 95), ('Michael T. Flynn', 90)]
# Kushner Strut
# [('1146 Kushner Strut', 95), ('1142 Kushner Strut', 95)]
# Cook
# [('J. Cooke ed', 90)]
# 1023
# Dmitri Klimentov
# [('Dmitri Klimentov,560', 95), ('Klimentov', 90)]
# Washington
# [('Washington DC', 95), ('Washington, D.C.', 90)]
# Michael Cohen Overview
# [('Michael Cohen Michael Cohen', 95)]
# Mtty Cofltftifl
# [('Cofl', 90)]
# 1007
# Gauhar-000057
# [('Gauhar-000058', 92), ('Gauhar-000059', 92)]
# Prodttet
# [('Prodttet II', 95), ('Nork Prodttet', 90)]
# Mttterittl Preteetecl
# [('Mttterittl Preteeteti', 90)]
# 992
# Raffel
# [('Josh Raffel', 90), ('Erik Raffel', 90)]
# 980
# Donbas
# [('Donbas.962', 90)]
# Jared C. Kushner
# [('Jared', 90)]
# Chris Christie.215
# [('Chris Christie', 95)]
# Ivan Nechepurenko
# [('54 Ivan Nechepurenko', 95)]
# 966
# AtterAey Wark Pret
# [('erAe~', 90), ('AtterAey', 90)]
# Facebook
# [('Facebook Message', 90), ('Facebook ID l', 90)]
# Roger Stone
# [('Roger Stone,73', 95), ('Roger Stone.1005', 95), ('Roger Stone 1 I. US', 90)]
# 949
# Jefferson III
# [('Jefferson', 95)]
# Cf Nixon
# [('Nixon', 90)]
# 937
# the United Arab Emirates
# [("the United Arab Emirates's", 96)]
# 926
# Josh Ragin
# [('Josh Rasin', 90), ('Josh Rogin', 90)]
# 914
# Eisenberg 1 l
# [('Eisenberg l l', 95), ('Eisenberg', 95)]
# 902
# eer Fee
# [('Eier Fee', 93)]
# 891
# Werk Pt'eettet
# [("Werk Pt'eelttet", 97)]
# Bobby
# [('Bobby Kennedy', 90)]
# 879
# Werk Prmhtet
# [('Werk Prm', 90)]
# 868
# Crown Prince Mohammed.995 Nader
# [('Crown Prince', 90)]
# 857
# Richardson
# [('Lakisha Richardson', 90)]
# May Cei
# [('Cei', 90)]
# 845
# Cottta
# [('Cotttaitt', 90), ('CotttaiH Material Proteeteti', 90)]
# eFittl
# [('Mutefittl Pfoteetea UHaef Fee', 90)]
# 832
# Lanny Davis
# [('Davis', 90)]
# Sergei Ivanov.348 Cohen
# [('Sergei Ivanov', 90)]
# 820
# Ushakov
# [('Yuri Ushakov', 90)]
# Sandra Luff
# [('Luff', 90)]
# Michael T. Flynn 1245
# [('Michael T Flynn', 95)]
# 807
# I. DCLeaks
# [('DC', 90)]
# I. Corney
# [("I. Corney's", 95)]
# Aguilar
# [('Aguilar-that', 90)]
# 794
# Dvoskin
# [('Evgeny Dvoskin', 90), ('Arkady Dvoskin', 90)]
# Hunt-000017
# [('Hunt-000051', 91)]
# JJ
# [('Jj', 100)]
# 780
# 770
# Mey CeHtttiH
# [('Moy CeHtttiH', 92)]
# Catherine Vargas
# [('Vargas', 90)]
# 758
# Rod J. Rosenstein
# [('Rod Rosenstein', 95), ('Rosenstein', 90)]
# DCCC networks.127
# [('DCCC', 90)]
# 745
# R. C1·iffl
# [('R. Ct1iffl', 90)]
# 734
# Flynn Statement of Offense
# [('Flynn Statement of Offense iJ3(g', 95), ('Flynn Statement', 90)]
# 722
# Wefk Pfetittet //
# [('Pfet', 90)]
# Proteetea
# [('CoAtaiA Material Proteetea UAeer', 90), ('Proteetea UHaef Fee', 90)]
# Edward Glassner
# [('Glassner', 90)]
# 708
# 116 Ken Bensinger et al.
# [('Ken Bensinger et al', 95)]
# Michael Glassner
# [('Michael G.', 90)]
# 344 Coats
# [('Coats', 90)]
# Elena Poliakova
# [('Poliakova', 90)]
# 694
# Flynn 11/20/17 302
# [('Flynn 11/21/17 302', 94)]
# 683
# SC_AD_00347
# [('SC_AD', 90)]
# Hillary Clinton."51 3
# [('Hillary Clinton."713', 93)]
# May Cm1taifl
# [('May Cm~taifl', 92)]
# 670
# Matefial
# [('Matefial Pfeteeted Ufl:', 90), ('Cetttaitt Matefial Pfeteetecl', 90)]
# 658
# Hope
# [('Hope Hicks', 90)]
# Andrew McCord
# [('McCord', 90)]
# Page et al
# [('Page et al.', 100)]
# 645
# Hawker
# [('Ł Jonathan Hawker', 90)]
# 634
# Pamela Brown et al
# [('Brown', 90)]
# I. Kaveladze
# [('A. Kaveladze', 92)]
# 622
# Millian
# [('Sergei Millian', 90)]
# 611
# 928 Cohen 9/12/18
# [('987 Cohen 9/12/18', 94)]
# 600
# Asatryan
# [('Georgi Asatryan', 90)]
# 589
# 579
# 569
# O'Brien et al
# [("O'Brien", 90)]
# Rinat Akhmetov
# [('Akhmetov', 90)]
# Uf'leer
# [('Ufleer', 92)]
# 556
# Annie Donaldson
# [('Donaldson', 90)]
# 545
# 535
# Tsekhomsky
# [('Nikolay Tsekhomsky', 90)]
# 524
# Katelyn Polantz et al
# [('Katelyn Polantz', 95)]
# 513
# SC_AD_00206
# [('SC_AD_00265', 91)]
# 502
# 492
# government.532
# [('government."320', 90)]
# Dole
# [('Bob Dole', 90)]
# 480
# 470
# Morrison
# [('Morrison v. Olson', 90)]
# Ukraine.884 Gates
# [('Ukraine', 90)]
# 458
# 448
# 438
# Bush
# [('George H.W. Bush', 90), ('George W. Bush', 90)]
# 426
# Gistaro
# [('investigation.341 Edward Gistaro', 90)]
# Mark Corallo
# [('Corallo', 90)]
# Luff 1/30/18 302
# [('Luff 1 /30/18', 95)]
# 413
# Depa1tment
# [('Depattment', 90)]
# 402
# 392
# 382
# Bossert
# [('Anna Bossert', 90)]
# 371
# Law
# [('Law Practice', 90), ('Law Jared Kushner', 90)]
# 359
# 349
# Robert Kennedy
# [('Kennedy', 90)]
# 338
# 328
# 318
# Christopher Steele &
# [('Christopher Steele', 100)]
# 307
# Pmter 4/13/18
# [('Pmter', 90)]
# 296
# Denis Klimentov
# [('Denis Klimentov-Zakharova', 90)]
# John Jr. Podobnyy
# [('Podobnyy', 90), ('Podobn', 90)]
# 283
# Evgeney
# [('Evgeney Eisenberg', 90)]
# 272
# LTG Flynn's
# [('LTG Flynn', 95)]
# 261
# 251
# 241
# 231
# 221
# 211
# 201
# 191
# 181
# 171
# 161
# Yevgeniy Viktorovich Prigozhin
# [('Yevgeniy Viktorovich', 90)]
# 150
# I. R. Criffl
# [('R. Criffl', 95), ('I. R. Criffi', 92)]
# 138
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '·']
# 128
# 118
# 108
# 98
# 88
# Mira Duma-
# [('Duma', 90)]
# 77
# 67
# 57
# Wark Praattet
# [('Praattet', 90)]
# 46
# 36
# H.B.
# [('55th Birthda Dear Boss', 90)]
# 25
# 15
# 5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-138-eae0453090b2> in <module>()
#       3     if(i%10 == 0):
#       4         print(len(distinctEnts))
# ----> 5     searchTerm = distinctEnts.pop(0)
#       6     matchList = process.extractBests(searchTerm, distinctEnts[1:],score_cutoff=90)
#       7
#
# IndexError: pop from empty list

# %%
matchList[0][0]
# Out:
# 'Donald Trump Jr'

# %%
def from_nx(graphVizNet, nx_graph):
        """
        This method takes an exisitng Networkx graph and translates
        it to a PyVis graph format that can be accepted by the VisJs
        API in the Jinja2 template. This operation is done in place.

        :param nx_graph: The Networkx graph object that is to be translated.
        :type nx_graph: networkx.Graph instance
        >>> nx_graph = Networkx.cycle_graph()
        >>> nt = Network("500px", "500px")
        # populates the nodes and edges data structures
        >>> nt.from_nx(nx_graph)
        >>> nt.show("nx.html")
        """
        assert(isinstance(nx_graph, networkx.Graph))
        edges = nx_graph.edges(data=True)
        nodes = nx_graph.nodes()
        if len(edges) > 0:
            for e in edges:
                graphVizNet.add_node(e[0], e[0], title=str(e[0]), color = nx_graph.node[e[0]]['color'], value = nx_graph.node[e[0]]['value'])
                graphVizNet.add_node(e[1], e[1], title=str(e[1]), color = nx_graph.node[e[1]]['color'], value = nx_graph.node[e[1]]['value'])
                graphVizNet.add_edge(e[0], e[1], value = nx_graph.edges[e[0],e[1]]['weight'])
        else:
            graphVizNet.add_nodes(nodes)
        return graphVizNet

# %%
import palettable
# selectedColors = palettable.colorbrewer.sequential.Blues_4.hex_colors
selectedColors = palettable.cartocolors.diverging.Earth_7.hex_colors[-5:]
selectedColors
# Out:
# ['#D6BD8D', '#EDEAC2', '#B5C8B8', '#79A7AC', '#2887A1']

# %%
numParagraphs = len(nlpParagraphs)
minConnections = 3

G = networkx.Graph()
G.clear()

colorMap = {'GPE':'Blue','PERSON':'Red','ORG':'Green','THEME':'Black'}
#nodeTypes = ['GPE','PERSON','ORG','THEME']
#colorMap = {nType:selectedColors[i] for i,nType in enumerate(nodeTypes)}
print(colorMap)
entCount = 0
for parNum, doc in enumerate(nlpParagraphs[0:numParagraphs]):
    G.add_node(f"par_{parNum}", t = 'Paragraph', color = 'grey')
    entCount = 0
    
    entCountDict = Counter([(ent.string.strip(),ent.label_) for ent in doc.ents if not bool(re.search(r":|\.", ent.text))  and (ent.label_=='GPE' or ent.label_ =='PERSON' or ent.label_ =='THEME')])

    for ent,cnt in entCountDict.items():
        G.add_node(ent[0],label = ent[1], color = colorMap[ent[1]])
        G.add_edge(ent[0],f"par_{parNum}", weight = cnt)#math.log(cnt + 1))
    if len(entCountDict) <minConnections:
        G.remove_node(f"par_{parNum}")
        
nodesToRemove = []
for node in G.nodes():
    nodeDegree = G.degree(node)
    if nodeDegree>1:
        G.node[node]['value'] = nodeDegree
    else:
        nodesToRemove.append(node)

for node in nodesToRemove:
    G.remove_node(node)
# Out:
# {'GPE': 'Blue', 'PERSON': 'Red', 'ORG': 'Green', 'THEME': 'Black'}

# %%
from pyvis.network import Network
pyvisG = Network("1000px", "1000px")
from_nx(pyvisG,G)
# Out:
# <class 'pyvis.network.Network'> |N|=1184 |E|=4,255

# %%
pyvisG.show_buttons(filter_=['physics'])

pyvisG.show('myGraph.html')

# %%
plt.figure(figsize=(5,5))
networkx.draw(G)

# %%
d = networkx.algorithms.pagerank(G)
print(d.__class__)
pageRank = pd.DataFrame([d]).T
# Out:
# <class 'dict'>

# %%
pageRank.sort_values(0, ascending = False).head(10)
# Out:
#                       0
# Russia         0.030103
# Cohen          0.022387
# Corney         0.021937
# Flynn          0.020361
# United States  0.012180
# Papadopoulos   0.011256
# McGahn         0.011012
# Manafort       0.009693
# Clinton        0.009310
# Trump          0.008640

# %%
plt.figure(figsize=(5,5))
networkx.draw(G)

# %%
def getSecondOrderSubgraph(graph, node):
    nodes = []
    for neighbor_list in [graph.neighbors(n) for n in graph.neighbors(node)]:
        for n in neighbor_list:
            nodes.append(n)
    nodes += [n for n in graph.neighbors(node)]
    subG = graph.subgraph(nodes)
    print(f"Nodes: {subG.number_of_nodes()}")
    print(f"Edges: {subG.number_of_edges()}")
    print(f"Self Loops: {subG.number_of_selfloops()}")
    return subG

# %%
subGraph = getSecondOrderSubgraph(G,'Cetttaitt')
# Out:
# Nodes: 37
# Edges: 41
# Self Loops: 0

# %%
pyvisG = Network("500px", "500px")
from_nx(pyvisG,subGraph)
#pyvisG.show_buttons(filter_=['physics'])
pyvisG.show('testSubgraph.html')
#pyvisG.show('C:/Users/mj514/Documents/blogdownBlog/blog/content/page/test.html')

# %%
import random
import numpy as np

import numpy as np

nxG = G

startingNodes = nxG.nodes()
numWalks = 100000

walkLengths = np.random.normal(15, 3, numWalks).astype(int)
walkLengths[walkLengths < 0] = 3 # has to do three walks

walks = []
print(random.choice(list(startingNodes)))
for walkLen in walkLengths:
    start = random.choice(list(startingNodes))
    if nxG.degree(start) > 0: #Check if the starting node has neighbors
        walk = [start]

        for step in range(walkLen):
            #print(f"onNode: {walk}")
            paths = [n for n in nxG.neighbors(walk[-1])]
            #print(paths)
            walk.append(random.choice(paths))
        walks.append(walk)
# Out:
# Nixon

# %%
random.choice(list(startingNodes))
# Out:
# 'SC_AD'

# %%
from gensim.models import Word2Vec
w2vModel = Word2Vec(walks, size=50, window=5, min_count=1, workers=16)

# %%
w2vModel.wv.most_similar('Moscow')
# Out:
# [('Agalarov', 0.5426560640335083),
#  ('New York', 0.4496534466743469),
#  ('Page', 0.4484499990940094),
#  ('Denysyk', 0.44486236572265625),
#  ('Rtskhiladze', 0.4418098032474518),
#  ('Emin Agalarov', 0.4351774752140045),
#  ('Ike', 0.4085486829280853),
#  ('Dvorkovich', 0.4046424627304077),
#  ('Baranov', 0.40399712324142456),
#  ('par_102', 0.3853163421154022)]

# %%
w2vModel.most_similar(positive=['Russia', 'New York'], negative=['Moscow'])
# Out:
# DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead). [ipykernel_launcher.py:1]
# [('Kushner', 0.3392045795917511),
#  ('the United States', 0.33620694279670715),
#  ('Ukraine', 0.3191729187965393),
#  ('Gates', 0.3186876177787781),
#  ('Boyarkin', 0.31401193141937256),
#  ('Cuba', 0.30333369970321655),
#  ('Trump', 0.3012174367904663),
#  ('Manafort', 0.300853967666626),
#  ('Petr Aven', 0.29667022824287415),
#  ('Manafmt', 0.294940710067749)]

# %%
w2vModel.most_similar(positive=['Russia', 'Ukraine'], negative=['Moscow'])
# Out:
# DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead). [ipykernel_launcher.py:1]
# [('Manafort', 0.5215727090835571),
#  ('Boyarkin', 0.4713065028190613),
#  ('Cuba', 0.4705045819282532),
#  ('Deripaska', 0.46969106793403625),
#  ('Pericles', 0.4652079641819),
#  ('Madrid', 0.44898107647895813),
#  ('Oleg Deripaska', 0.4335271120071411),
#  ('Kilimnik', 0.42099225521087646),
#  ('Landrum', 0.41017675399780273),
#  ('Neil MacFarquhar', 0.4059590995311737)]

# %%
import numpy as np
walkLength = np.random.normal(15, 3, 10).astype(int)
walkLength[walkLength < 0] = 3 # has to do three walks
# Out:
# array([20, 14, 15, 14, 13, 12, 18, 14, 14, 12])

# %%
networkx.draw(russiaSubgraph,with_labels=True)

# %%
[n for n in G.neighbors('Ivanka Trump')]
# Out:
# ['par_160', 'par_177', 'par_251']

# %%
nodes = []
for neighbor_list in [G.neighbors(n) for n in G.neighbors('Ivanka Trump')]:
        for n in neighbor_list:
            nodes.append(n)

# %%
russiaSubgraph.number_of_nodes()
# Out:
# 1901

# %%
G.node['Implantation ofMalware']
# Out:
# {'label': 'PERSON', 'color': 'Red', 'value': 0}

# %%
[G.neighbors(n) for n in G.neighbors('Ivanka Trump')]
